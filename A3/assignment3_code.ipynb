# %%
from datasets import load_dataset
dataset = load_dataset('climate_fever')['test']
print(dataset['claim'])

import logging
import os
from gensim.models import Word2Vec
import gensim.models
from sklearn.model_selection import train_test_split
from sklearn.metrics.pairwise import cosine_similarity
from datasets import load_dataset
dataset = load_dataset('climate_fever')['test']
#print(dataset['claim'])

from matplotlib import pyplot as plt;
import numpy as np

#convert to vectors
class generate_key:
    def __init__(self,sentences):
        self.sentences=sentences
        
    def __iter__(self):
        for sentence in self.sentences:
            yield(gensim.utils.simple_preprocess(str(sentence)))

#word2vec model
data = generate_key(dataset['claim'])#feature dataset and convert every word to vectors
w2v_model = gensim.models.Word2Vec(data, size=100, min_count=1, window=5, iter=50)
#trian model
w2v_model.train(generate_key(dataset['claim']),total_examples=w2v_model.corpus_count, epochs=30, report_delay=1)

#target dataset
data_label = dataset['claim_label']

# iterate through each sentence in the file 
data = []
for i in range(len(dataset['claim'])):
    temp = [] 
    splited_string=dataset['claim'][i].split(' ')
    print(splited_string)
    for j in range(len(splited_string)):
        try:
            temp.append(w2v_model.wv[splited_string[j].lower()])
        except BaseException:
            print(splited_string[j].lower())
    data.append(temp)

# Split data into train-val-test sets with portions 80-10-10 percent
# x_feature = generate_key(dataset['claim']'
y_target = generate_key(dataset['claim_label'])
x_train,x_test,y_train,y_test= train_test_split(data,data_label,test_size=0.2,random_state=0)#x:feature y:target and set random state to zero

print(len(x_train),len(y_train))

#cosine similarity measure
import gensim
import numpy
# CBOW model 
# Print results 
print("Cosine similarity between 'extremes' " + "and 'weather' - CBOW : ", w2v_model.similarity('extremes', 'weather')) 
print("Cosine similarity between 'greenhouse'" + "and 'gases' - CBOW : ", w2v_model.similarity('greenhouse', 'gases'))
print("Cosine similarity between 'greenhouse' " + "and 'humans' - CBOW : ", w2v_model.similarity('greenhouse', 'humans'))
print("Cosine similarity between 'greenhouse' " + "and 'activities' - CBOW : ", w2v_model.similarity('greenhouse', 'activities'))
print("Cosine similarity between 'greenhouse' " + "and 'problem' - CBOW : ", w2v_model.similarity('greenhouse', 'problem'))
print("Cosine similarity between 'greenhouse' " + "and 'atmosphere' - CBOW : ", w2v_model.similarity('greenhouse', 'atmosphere'))
print("Cosine similarity between 'greenhouse' " + "and 'carbon' - CBOW : ", w2v_model.similarity('atmosphere', 'carbon'))
print("Cosine similarity between 'greenhouse' " + "and 'dioxide' - CBOW : ", w2v_model.similarity('greenhouse', 'dioxide'))
print("Cosine similarity between 'climate' " + "and 'change' - CBOW : ", w2v_model.similarity('climate', 'change'))

import numpy as np
A = np.array(x_train[0])
print(w2v_model.wv.most_similar(positive=["sun", "cold"], negative=["hot"], topn=3))
print(w2v_model.wv.most_similar(positive=["temperature", "raise"], negative=["cold"], topn=3))
print(w2v_model.wv.most_similar(positive=["temperature", "cold"], negative=["hot"], topn=3))
print(w2v_model.wv.most_similar(positive=["weather", "cold"], negative=["hot"], topn=3))
print(w2v_model.wv.most_similar(positive=["earth", "life"], negative=["carbon"], topn=3))
print(w2v_model.wv.most_similar(positive=["atmospheric", "cold"], negative=["carbon"], topn=3))

import logging
import os
from gensim.models import Word2Vec
import gensim.models
import gensim.downloader

print(list(gensim.downloader.info()['models'].keys()))

glove_vectors = gensim.downloader.load('glove-wiki-gigaword-50')
word2vec_vectors=gensim.downloader.load('word2vec-google-news-300')

score = glove_vectors.most_similar('temperature')

score_word = word2vec_vectors.most_similar('temperature')

print(score)
print(score_word)



'''
CM2: PCA model
'''
# sentence_data=dataset['claim']
# x_train,x_test = train_test_split(sentence_data,test_size=0.2,random_state=0)
#
# #Get the training model for part1
# w2v_model_train = gensim.models.Word2Vec(generate_key(x_train), size=100, min_count=1, window=5, iter=50)
# #train word2vec model
# w2v_model_train.train(generate_key(x_train), total_examples=w2v_model.corpus_count, epochs=30, report_delay=1)

#Now first step get the vector representation of each vocab
voc_list=[];
voc_embedlist=[];
for voc in w2v_model.wv.vocab:
    voc_list.append(voc)
    voc_embedlist.append(w2v_model.wv[voc])

voc_embedlist_train,voc_embedlist_test,voc_list_train,voc_list_test=train_test_split(voc_embedlist,voc_list,test_size=0.2,random_state=0)
#We must centralize the voc_embedlist_train and test
voc_embedlist_train=np.array(voc_embedlist_train)
mean_list=[]
for i in range(voc_embedlist_train.shape[1]):
    mean_list.append(voc_embedlist_train[:,i].mean())
mean_list=np.array(mean_list)
mean_list=mean_list.reshape(1,voc_embedlist_train.shape[1])
#Centeralize
voc_embedlist_test=np.array(voc_embedlist_test)
voc_embedlist_train=voc_embedlist_train-mean_list
voc_embedlist_test=voc_embedlist_test-mean_list
#Then perform PCA on voc_embedlist

from matplotlib.pyplot import MultipleLocator
from sklearn.decomposition import PCA
import pandas as pd;
import seaborn as sns;
covar_matrix=PCA(n_components=voc_embedlist_train.shape[1])
covar_matrix.fit(voc_embedlist_train)
#three_dim = PCA(random_state=0).fit_transform(voc_embedlist)[:,:3]
# x_major_locator=MultipleLocator(1)
# ax=plt.gca()
# ax.xaxis.set_major_locator(x_major_locator)
# plt.xlim(-0.5,30)
plt.plot(covar_matrix.explained_variance_)
plt.xlabel('Numbers',fontsize=14)
plt.title('Eigenvalues of PCA')
plt.ylabel('Eigenvalues')
plt.xlabel('Component')
plt.show()
#Closer look scree plot
x_major_locator=MultipleLocator(1)
ax=plt.gca()
ax.xaxis.set_major_locator(x_major_locator)
plt.xlim(-0.5,30)
plt.plot(covar_matrix.explained_variance_)
plt.xlabel('Numbers',fontsize=14)
plt.title('Eigenvalues of PCA')
plt.ylabel('Eigenvalues')
plt.xlabel('Component')
plt.show()

#We set the components to 12;

n_component=12;
covar_matrix=PCA(n_components=n_component)
covar_matrix.fit(voc_embedlist_train)
#Apply on test set
data_pca_transform=covar_matrix.transform(voc_embedlist_test)
df = pd.DataFrame(data_pca_transform, columns = ['component1','component2','component3','component4','component5','component6','component7','component8','component9','component10','component11','component12'])
sns.pairplot(df,vars=['component1','component2','component3','component4'])
plt.show()
#Pair plot with text word information
PCA_features=['component1','component2','component3','component4']
for i in range(len(PCA_features)):
    for j in range(i+1,len(PCA_features)):
        plt.scatter(df[PCA_features[i]], df[PCA_features[j]], s=6)
        plt.xlabel(PCA_features[i])
        plt.ylabel(PCA_features[j])
        for k, txt in enumerate(voc_list_test):
            plt.text(df[PCA_features[i]][k], df[PCA_features[j]][k], txt, fontsize=6,color='r')
        plt.show()
#calculate the differences of cosine of two vectors
#Compare that value in Word2Vec embedding 100-D and PCA 10-D
cos_difference_pca=0
count=0;
for i in range(len(voc_list_test)):
    for j in range(i+1,len(voc_list_test)):
        count=count+1
        embed_similarity=cosine_similarity(voc_embedlist_test[i].reshape(1,voc_embedlist_test[0].shape[0]),voc_embedlist_test[j].reshape(1,voc_embedlist_test[0].shape[0]))
        pca_similarity=cosine_similarity(data_pca_transform[i].reshape(1,n_component),data_pca_transform[j].reshape(1,n_component))
        cos_difference_pca=cos_difference_pca+abs(pca_similarity[0][0]-embed_similarity)
cos_difference_pca=cos_difference_pca/count
print('The average cos difference between two vectors is:%.10f'%cos_difference_pca)

#Check the arithmetic
pca_vector=covar_matrix.transform(voc_embedlist)
#build dictionary
PCA_dic={}
count=0
for i in voc_list:
    PCA_dic[i]=pca_vector[count]
    count=count+1
#Some examples
temp=cosine_similarity((PCA_dic['sun']+PCA_dic['cold']-PCA_dic['hot']).reshape(1,12),PCA_dic['colder'].reshape(1,12))
print('the cosine between “sun” + “cold” – “hot” and “colder” in PCA model is %f'%temp)

temp=cosine_similarity((PCA_dic['temperature']+PCA_dic['raise']-PCA_dic['cold']).reshape(1,12),PCA_dic['seas'].reshape(1,12))
print('the cosine between “temperature” + “raise” – “cold” and “seas” in PCA model is %f'%temp)

temp=cosine_similarity((PCA_dic['sun']+PCA_dic['cold']-PCA_dic['hot']).reshape(1,12),PCA_dic['colder'].reshape(1,12))
print('the cosine between “temperature” + “cold” – “hot” and “latitude” in PCA model is %f'%temp)

temp=cosine_similarity((PCA_dic['weather']+PCA_dic['cold']-PCA_dic['hot']).reshape(1,12),PCA_dic['extreme'].reshape(1,12))
print('the cosine between “weather” + “cold” – “hot” and “extreme” in PCA model is %f'%temp)

temp=cosine_similarity((PCA_dic['earth']+PCA_dic['life']-PCA_dic['carbon']).reshape(1,12),PCA_dic['dead'].reshape(1,12))
print('the cosine between “earth” + “life” – “carbon” and “dead” in PCA model is %f'%temp)

temp=cosine_similarity((PCA_dic['atmosphere']+PCA_dic['cold']-PCA_dic['carbon']).reshape(1,12),PCA_dic['winter'].reshape(1,12))
print('the cosine between “atmosphere” + “cold” – “carbon” and “winter” in PCA model is %f'%temp)

'''
LLE method
'''
#Apply LLE method
import random
from sklearn.manifold import LocallyLinearEmbedding
#Tune the parameter of n_neighbors
best_k=1;
best_cos_difference_lle=10;
for k in range(3,100):
    LLE=LocallyLinearEmbedding(n_components=4,n_neighbors=k)
    cos_difference_lle=0
    count=0;
    data_lle_transform_test = LLE.fit_transform(voc_embedlist_test)
    #iterate 10000 times
    for iter in range(10000):
        voc1_pos=random.randint(0,voc_embedlist_test.shape[0]-1)
        voc2_pos=random.randint(0,voc_embedlist_test.shape[0]-1)
        count=count+1
        embed_similarity = cosine_similarity(voc_embedlist_test[voc1_pos].reshape(1, voc_embedlist_test[0].shape[0]),
                                             voc_embedlist_test[voc2_pos].reshape(1, voc_embedlist_test[0].shape[0]))
        lle_similarity=cosine_similarity(data_lle_transform_test[voc1_pos].reshape(1,4),data_lle_transform_test[voc2_pos].reshape(1,4))
        cos_difference_lle=cos_difference_lle+abs(lle_similarity[0][0]-embed_similarity)
    cos_difference_lle=cos_difference_lle/count
    if cos_difference_lle<best_cos_difference_lle:
        best_cos_difference_lle=cos_difference_lle
        best_k=k

best_k=49
#Apply the best parameter on test set
lle_components=4
LLE = LocallyLinearEmbedding(n_components=lle_components, n_neighbors=best_k)
data_lle_transform=LLE.fit_transform(voc_embedlist_test)
df_lle = pd.DataFrame(data_lle_transform, columns = ['component1','component2','component3','component4'])
sns.pairplot(df_lle,vars=['component1','component2','component3','component4'])
plt.show()

#calculate the differences of cosine of two vectors
#Pair plot with text word information
LLE_features=['component1','component2','component3','component4']
for i in range(len(LLE_features)):
    for j in range(i+1,len(LLE_features)):
        plt.scatter(df_lle[LLE_features[i]], df_lle[LLE_features[j]], s=6)
        plt.xlabel(LLE_features[i])
        plt.ylabel(LLE_features[j])
        for k, txt in enumerate(voc_list_test):
            plt.text(df_lle[LLE_features[i]][k], df_lle[LLE_features[j]][k], txt, fontsize=6,color='r')
        plt.show()

#Compare that value in Word2Vec embedding 100-D and LLE 4-D
cos_difference_lle=0
count=0;
for i in range(len(voc_list_test)):
    for j in range(i+1,len(voc_list_test)):
        count=count+1
        embed_similarity = cosine_similarity(voc_embedlist_test[i].reshape(1, voc_embedlist_test[0].shape[0]),
                                             voc_embedlist_test[j].reshape(1, voc_embedlist_test[0].shape[0]))
        lle_similarity=cosine_similarity(data_lle_transform[i].reshape(1,lle_components),data_lle_transform[j].reshape(1,lle_components))
        cos_difference_lle=cos_difference_lle+abs(lle_similarity[0][0]-embed_similarity)
cos_difference_lle=cos_difference_lle/count
print('The average cos difference between two vectors is:%.10f'%cos_difference_lle)
#Check the arithmetic
lle_vector=LLE.transform(voc_embedlist)
#build dictionary
lle_dic={}
count=0
for i in voc_list:
    lle_dic[i]=lle_vector[count]
    count=count+1
#Some examples
temp=cosine_similarity((lle_dic['sun']+lle_dic['cold']-lle_dic['hot']).reshape(1,4),lle_dic['colder'].reshape(1,4))
print('the cosine between “sun” + “cold” – “hot” and “colder” in LLE model is %f'%temp)

temp=cosine_similarity((lle_dic['temperature']+lle_dic['raise']-lle_dic['cold']).reshape(1,4),lle_dic['seas'].reshape(1,4))
print('the cosine between “temperature” + “raise” – “cold” and “seas” in LLE model is %f'%temp)

temp=cosine_similarity((lle_dic['sun']+lle_dic['cold']-lle_dic['hot']).reshape(1,4),lle_dic['colder'].reshape(1,4))
print('the cosine between “temperature” + “cold” – “hot” and “latitude” in LLE model is %f'%temp)

temp=cosine_similarity((lle_dic['weather']+lle_dic['cold']-lle_dic['hot']).reshape(1,4),lle_dic['extreme'].reshape(1,4))
print('the cosine between “weather” + “cold” – “hot” and “extreme” in LLE model is %f'%temp)

temp=cosine_similarity((lle_dic['earth']+lle_dic['life']-lle_dic['carbon']).reshape(1,4),lle_dic['dead'].reshape(1,4))
print('the cosine between “earth” + “life” – “carbon” and “dead” in LLE model is %f'%temp)

temp=cosine_similarity((lle_dic['atmosphere']+lle_dic['cold']-lle_dic['carbon']).reshape(1,4),lle_dic['winter'].reshape(1,4))
print('the cosine between “atmosphere” + “cold” – “carbon” and “winter” in LLE model is %f'%temp)

'''
t-SNE part
'''
import random
from sklearn.manifold import TSNE


#Apply the best parameter on test set
tsne_components=2
TSNE_model=TSNE(n_components=tsne_components)
data_tsne_transform=TSNE_model.fit_transform(voc_embedlist_test)

df_tsne = pd.DataFrame(data_tsne_transform, columns = ['component1','component2'])
sns.pairplot(df_tsne,vars=['component1','component2'])
plt.show()

#calculate the differences of cosine of two vectors
#Pair plot with text word information
tsne_features=['component1','component2']
for i in range(len(tsne_features)):
    for j in range(i+1,len(tsne_features)):
        plt.scatter(df_tsne[tsne_features[i]], df_tsne[tsne_features[j]], s=6)
        plt.xlabel(tsne_features[i])
        plt.ylabel(tsne_features[j])
        for k, txt in enumerate(voc_list_test):
            plt.text(df_tsne[tsne_features[i]][k], df_tsne[tsne_features[j]][k], txt, fontsize=6,color='r')
        plt.show()

#Compare that value in Word2Vec embedding 100-D and t-SNE 2-D
cos_difference_tsne=0
count=0;
for i in range(len(voc_list_test)):
    for j in range(i+1,len(voc_list_test)):
        count=count+1
        embed_similarity = cosine_similarity(voc_embedlist_test[i].reshape(1, voc_embedlist_test[0].shape[0]),
                                             voc_embedlist_test[j].reshape(1, voc_embedlist_test[0].shape[0]))
        tsne_similarity=cosine_similarity(data_tsne_transform[i].reshape(1,tsne_components),data_tsne_transform[j].reshape(1,tsne_components))
        cos_difference_tsne=cos_difference_tsne+abs(tsne_similarity[0][0]-embed_similarity)
cos_difference_tsne=cos_difference_tsne/count
print('The average cos difference between two vectors is:%.10f'%cos_difference_tsne)

#Check the arithmetic
TSNE_model=TSNE(n_components=tsne_components)
tsne_vector=TSNE_model.fit_transform(voc_embedlist)
#build dictionary
tsne_dic={}
count=0
for i in voc_list:
    tsne_dic[i]=tsne_vector[count]
    count=count+1
#Some examples
temp=cosine_similarity((tsne_dic['sun']+tsne_dic['cold']-tsne_dic['hot']).reshape(1,2),tsne_dic['colder'].reshape(1,2))
print('the cosine between “sun” + “cold” – “hot” and “colder” in t-SNE model is %f'%temp)

temp=cosine_similarity((tsne_dic['temperature']+tsne_dic['raise']-tsne_dic['cold']).reshape(1,2),tsne_dic['seas'].reshape(1,2))
print('the cosine between “temperature” + “raise” – “cold” and “seas” in t-SNE model is %f'%temp)

temp=cosine_similarity((tsne_dic['sun']+tsne_dic['cold']-tsne_dic['hot']).reshape(1,2),tsne_dic['colder'].reshape(1,2))
print('the cosine between “temperature” + “cold” – “hot” and “latitude” in t-SNE model is %f'%temp)

temp=cosine_similarity((tsne_dic['weather']+tsne_dic['cold']-tsne_dic['hot']).reshape(1,2),tsne_dic['extreme'].reshape(1,2))
print('the cosine between “weather” + “cold” – “hot” and “extreme” in t-SNE model is %f'%temp)

temp=cosine_similarity((tsne_dic['earth']+tsne_dic['life']-tsne_dic['carbon']).reshape(1,2),tsne_dic['dead'].reshape(1,2))
print('the cosine between “earth” + “life” – “carbon” and “dead” in t-SNE model is %f'%temp)

temp=cosine_similarity((tsne_dic['atmosphere']+tsne_dic['cold']-tsne_dic['carbon']).reshape(1,2),tsne_dic['winter'].reshape(1,2))
print('the cosine between “atmosphere” + “cold” – “carbon” and “winter” in t-SNE model is %f'%temp)
# Out:
# Using custom data configuration default
# Reusing dataset climate_fever (/Users/tangxikai/.cache/huggingface/datasets/climate_fever/default/1.0.1/3b846b20d7a37bc0019b0f0dcbde5bf2d0f94f6874f7e4c398c579f332c4262c)
# ['Global warming is driving polar bears toward extinction', 'The sun has gone into ‘lockdown’ which could cause freezing weather, earthquakes and famine, say scientists', 'The polar bear population has been growing.', "Ironic' study finds more CO2 has slightly cooled the planet", 'Human additions of CO2 are in the margin of error of current measurements and the gradual increase in CO2 is mainly from oceans degassing as the planet slowly emerges from the last ice age.', 'They tell us that we are the primary forces controlling earth temperatures by the burning of fossil fuels and releasing their carbon dioxide.', 'The Great Barrier Reef is experiencing the most widespread bleaching ever recorded', 'it’s not a pollutant that threatens human civilization.', 'If CO2 was so terrible for the planet, then installing a CO2 generator in a greenhouse would kill the plants.', 'Sea level rise has been slow and a constant, pre-dating industrialization', 'Earth about to enter 30-YEAR ‘Mini Ice Age’', 'Volcanoes Melting West Antarctic Glaciers, Not Global Warming', "the bushfires [in Australia] were caused by arsonists and a series of lightning strikes, not 'climate change'", 'Discovery Of Massive Volcanic CO2 Emissions Discredits Global Warming Theory', 'Harvard study finds that wind turbines create MORE global warming than the fossil fuels they eliminate', 'Ice berg melts, ocean level remains the same.', "When the exact same group of 'experts' who claimed it was global cooling in 1977 now claim it's global warming you can easily see why I am skeptical", 'Scientists studying Antarctica sea ice warn a rise in accumulation could spark the next ice age.', "More than 500 scientists and professionals in climate and related fields have sent a 'European Climate Declaration' to the Secretary-General of the United Nations", 'Unprecedented climate change has caused sea level at Sydney Harbour to rise approximately 0.0 cm over the past 140 years.', 'Human-produced carbon might be one of the factors [of climate change], but there’s simply no evidence that it is a significant one.', 'CO2 does not cause climate change, it RESPONDS to it [...]', '[T]he raw data, the actual thermometer data[...] shows that the US has been cooling for 80 to 90 years.', 'Earth’s mean temperature over the last 2,000 years shows two previous periods when temperatures were warmer than they are now; from 1–200 A.D., an epoch called the Roman Warm Period, and more recently the Medieval Warm Period from 900–1100 A.D.', 'So that means that probably about half, maybe half of that nine-tenths of the degree [of total warming] might be caused by greenhouse gases', '[NASA] has been adjusting temperatures from the past[...]', 'A windmill could spin until it falls apart and never generate as much energy as was invested in building it.', 'Fifty-five thousand years ago the whole world was 2°C warmer than it is today[...]', 'Sea level rise is not going to happen.', 'Cold weather to grip world as solar minimum to deepen, NASA says', '[O]ne of the previously fastest shrinking glaciers in the world is growing again, calling into question the narrative that rapid climate change [...]', 'The models predicted about three times the amount of warming in the world we’ve seen since [1988].', 'The science is clear, climate change is making extreme weather events, including tornadoes, worse.', 'Burping cows are more damaging to the climate than all the cars on this planet.', '[S]unspot activity on the surface of our star has dropped to a new low.', 'The rate of warming according to the data is much slower than the models used by the IPCC', 'The \xadatmospheric residency time of carbon dioxide is five years', 'Sea-level rise does not seem to depend on ocean temperature, and certainly not on CO2', 'There isn’t yet any empirical evidence for their claim that greenhouse gases even cause temperatures to increase.', 'NOAA has adjusted past temperatures to look colder than they were and recent temperatures to l ...
# Using custom data configuration default
# Reusing dataset climate_fever (/Users/tangxikai/.cache/huggingface/datasets/climate_fever/default/1.0.1/3b846b20d7a37bc0019b0f0dcbde5bf2d0f94f6874f7e4c398c579f332c4262c)
# ['Global', 'warming', 'is', 'driving', 'polar', 'bears', 'toward', 'extinction']
# ['The', 'sun', 'has', 'gone', 'into', '‘lockdown’', 'which', 'could', 'cause', 'freezing', 'weather,', 'earthquakes', 'and', 'famine,', 'say', 'scientists']
# ‘lockdown’
# weather,
# famine,
# ['The', 'polar', 'bear', 'population', 'has', 'been', 'growing.']
# growing.
# ["Ironic'", 'study', 'finds', 'more', 'CO2', 'has', 'slightly', 'cooled', 'the', 'planet']
# ironic'
# co2
# ['Human', 'additions', 'of', 'CO2', 'are', 'in', 'the', 'margin', 'of', 'error', 'of', 'current', 'measurements', 'and', 'the', 'gradual', 'increase', 'in', 'CO2', 'is', 'mainly', 'from', 'oceans', 'degassing', 'as', 'the', 'planet', 'slowly', 'emerges', 'from', 'the', 'last', 'ice', 'age.']
# co2
# co2
# age.
# ['They', 'tell', 'us', 'that', 'we', 'are', 'the', 'primary', 'forces', 'controlling', 'earth', 'temperatures', 'by', 'the', 'burning', 'of', 'fossil', 'fuels', 'and', 'releasing', 'their', 'carbon', 'dioxide.']
# dioxide.
# ['The', 'Great', 'Barrier', 'Reef', 'is', 'experiencing', 'the', 'most', 'widespread', 'bleaching', 'ever', 'recorded']
# ['it’s', 'not', 'a', 'pollutant', 'that', 'threatens', 'human', 'civilization.']
# it’s
# a
# civilization.
# ['If', 'CO2', 'was', 'so', 'terrible', 'for', 'the', 'planet,', 'then', 'installing', 'a', 'CO2', 'generator', 'in', 'a', 'greenhouse', 'would', 'kill', 'the', 'plants.']
# co2
# planet,
# a
# co2
# a
# plants.
# ['Sea', 'level', 'rise', 'has', 'been', 'slow', 'and', 'a', 'constant,', 'pre-dating', 'industrialization']
# a
# constant,
# pre-dating
# industrialization
# ['Earth', 'about', 'to', 'enter', '30-YEAR', '‘Mini', 'Ice', 'Age’']
# 30-year
# ‘mini
# age’
# ['Volcanoes', 'Melting', 'West', 'Antarctic', 'Glaciers,', 'Not', 'Global', 'Warming']
# glaciers,
# ['the', 'bushfires', '[in', 'Australia]', 'were', 'caused', 'by', 'arsonists', 'and', 'a', 'series', 'of', 'lightning', 'strikes,', 'not', "'climate", "change'"]
# [in
# australia]
# a
# strikes,
# 'climate
# change'
# ['Discovery', 'Of', 'Massive', 'Volcanic', 'CO2', 'Emissions', 'Discredits', 'Global', 'Warming', 'Theory']
# co2
# ['Harvard', 'study', 'finds', 'that', 'wind', 'turbines', 'create', 'MORE', 'global', 'warming', 'than', 'the', 'fossil', 'fuels', 'they', 'eliminate']
# ['Ice', 'berg', 'melts,', 'ocean', 'level', 'remains', 'the', 'same.']
# melts,
# same.
# ['When', 'the', 'exact', 'same', 'group', 'of', "'experts'", 'who', 'claimed', 'it', 'was', 'global', 'cooling', 'in', '1977', 'now', 'claim', "it's", 'global', 'warming', 'you', 'can', 'easily', 'see', 'why', 'I', 'am', 'skeptical']
# 'experts'
# 1977
# it's
# i
# ['Scientists', 'studying', 'Antarctica', 'sea', 'ice', 'warn', 'a', 'rise', 'in', 'accumulation', 'could', 'spark', 'the', 'next', 'ice', 'age.']
# a
# age.
# ['More', 'than', '500', 'scientists', 'and', 'professionals', 'in', 'climate', 'and', 'related', 'fields', 'have', 'sent', 'a', "'European", 'Climate', "Declaration'", 'to', 'the', 'Secretary-General', 'of', 'the', 'United', 'Nations']
# 500
# a
# 'european
# declaration'
# secretary-general
# ['Unprecedented', 'climate', 'change', 'has', 'caused', 'sea', 'level', 'at', 'Sydney', 'Harbour', 'to', 'rise', 'approximately', '0.0', 'cm', 'over', 'the', 'past', '140', 'years.']
# 0.0
# 140
# years.
# ['Human-produced', 'carbon', 'might', 'be', 'one', 'of', 'the', 'factors', '[of', 'climate', 'change],', 'but', 'there’s', 'simply', 'no', 'evidence', 'that', 'it', 'is', 'a', 'significant', 'one.']
# human-produced
# [of
# change],
# there’s
# a
# one.
# ['CO2', 'does', 'not', 'cause', 'climate', 'change,', 'it', 'RESPONDS', 'to', 'it', '[...]']
# co2
# change,
# [...]
# ['[T]he', 'raw', 'data,', 'the', 'actual', 'thermometer', 'data[...]', 'shows', 'that', 'the', 'US', 'has', 'been', 'cooling', 'for', '80', 'to', '90', 'years.']
# [t]he
# data,
# data[...]
# 80
# 90
# years.
# ['Earth’s', 'mean', 'temperature', 'over', 'the', 'last', '2,000', 'years', 'shows', 'two', 'previous', 'periods', 'when', 'temperatures', 'were', 'warmer', 'than', 'they', 'are', 'now;', 'from', '1–200', 'A.D.,', 'an', 'epoch', 'called', 'the', 'Roman', 'Warm', 'Period,', 'and', 'more', 'recently', 'the', 'Medieval', 'Warm', 'Period', 'from', '900–1100', 'A.D.']
# earth’s
# 2,000
# now;
# 1–200
# a.d.,
# period,
# 900–1100
# a.d.
# ['So', 'that', 'means', 'that', 'probably', 'about', 'half,', 'maybe', 'half', 'of', 'that', 'nine-tenths', 'of', 'the', 'degree', '[of', 'total', 'warming]', 'might', 'be', 'caused', 'by', 'greenhouse', 'gases']
# half,
# nine-tenths
# [of
# warming]
# ['[NASA]', 'has', 'been', 'adjusting', 'temperatures', 'from', 'the', 'past[...]']
# [nasa]
# past[...]
# ['A', 'windmill', 'could', 'spin', 'until', 'it', 'falls', 'apart', 'and', 'never', 'generate', 'as', 'much', 'energy', 'as', 'was', 'invested', 'in', 'building', 'it.']
# a
# it.
# ['Fifty-five', 'thousand', 'years', 'ago', 'the', 'whole', 'world', 'was', '2°C', 'warmer', 'than', 'it', 'is', 'today[...]']
# fifty-five
# 2°c
# today[...]
# ['Sea', 'level', 'rise', 'is', 'not', 'going', 'to', 'happen.']
# happen.
# ['Cold', 'weather', 'to', 'grip', 'world', 'as', 'solar', 'minimum', 'to', 'deepen,', 'NASA', 'says']
# deepen,
# ['[O]ne', 'of', 'the', 'previously', 'fastest', 'shrinking', 'glaciers', 'in', 'the', 'world', 'is', 'growing', 'again,', 'calling', 'into', 'question', 'the', 'narrative', 'that', 'rapid', 'climate', 'change', '[...]']
# [o]ne
# again,
# [...]
# ['The', 'models', 'predicted', 'about', 'three', 'times', 'the', 'amount', 'of', 'warming', 'in', 'the', 'world', 'we’ve', 'seen', 'since', '[1988].']
# we’ve
# [1988].
# ['The', 'science', 'is', 'clear,', 'climate', 'change', 'is', 'making', 'extreme', 'weather', 'events,', 'including', 'tornadoes,', 'worse.']
# clear,
# events,
# tornadoes,
# worse.
# ['Burping', 'cows', 'are', 'more', 'damaging', 'to', 'the', 'climate', 'than', 'all', 'the', 'cars', 'on', 'this', 'planet.']
# planet.
# ['[S]unspot', 'activity', 'on', 'the', 'surface', 'of', 'our', 'star', 'has', 'dropped', 'to', 'a', 'new', 'low.']
# [s]unspot
# a
# low.
# ['The', 'rate', 'of', 'warming', 'according', 'to', 'the', 'data', 'is', 'much', 'slower', 'than', 'the', 'models', 'used', 'by', 'the', 'IPCC']
# ['The', '\xadatmospheric', 'residency', 'time', 'of', 'carbon', 'dioxide', 'is', 'five', 'years']
# ­atmospheric
# ['Sea-level', 'rise', 'does', 'not', 'seem', 'to', 'depend', 'on', 'ocean', 'temperature,', 'and', 'certainly', 'not', 'on', 'CO2']
# sea-level
# temperature,
# co2
# ['There', 'isn’t', 'yet', 'any', 'empirical', 'evidence', 'for', 'their', 'claim', 'that', 'greenhouse', 'gases', 'even', 'cause', 'temperatures', 'to', 'increase.']
# isn’t
# increase.
# ['NOAA', 'has', 'adjusted', 'past', 'temperatures', 'to', 'look', 'colder', 'than', 'they', 'were', 'and', 'recent', 'temperatures', 'to', 'look', 'warmer', 'than', 'they', 'were.']
# were.
# ['They', 'were', 'going', 'to', 'be', 'gone', 'by', 'now,', 'but', 'now', "they're", 'setting', 'records']
# now,
# they're
# ['unadjusted', 'data', 'suggests', 'that', 'temperatures', 'in', 'Australia', 'have', 'only', 'increased', 'by', '0.3', 'degrees', 'over', 'the', 'past', 'century,', 'not', 'the', '1', 'degree', 'usually', 'claimed']
# 0.3
# century,
# 1
# ['[climate', 'scientists]', 'say', 'that', 'aspects', 'of', 'the', 'case', 'of', 'Hurricane', 'Harvey', 'suggest', 'global', 'warming', 'is', 'making', 'a', 'bad', 'situation', 'worse.']
# [climate
# scientists]
# a
# worse.
# ['The', 'IPCC,', 'the', 'Intergovernmental', 'Panel', 'on', 'Climate', 'Change,', 'which', 'is', 'sort', 'of', 'the', 'voice', 'of', 'the', 'consensus,', 'concedes', 'that', 'there', 'has', 'been', 'no', 'increase', 'in', 'extreme', 'weather', 'events.']
# ipcc,
# intergovernmental
# change,
# consensus,
# events.
# ['according,', 'again,', 'to', 'the', 'official', 'figures—during', 'this', 'past', '10', 'years,', 'if', 'anything,', 'mean', 'global', 'temperature,', 'average', 'world', 'temperature,', 'has', 'slightly', 'declined']
# according,
# again,
# figures—during
# 10
# years,
# anything,
# temperature,
# temperature,
# ["Trump's", 'action', 'could', 'push', 'the', 'Earth', 'over', 'the', 'brink,', 'to', 'become', 'like', 'Venus,', 'with', 'a', 'temperature', 'of', 'two', 'hundred', 'and', 'fifty', 'degrees,', 'and', 'raining', 'sulphuric', 'acid.']
# trump's
# brink,
# venus,
# a
# degrees,
# acid.
# ['Most', 'likely', 'the', 'primary', 'control', 'knob', '[on', 'climate', 'change]', 'is', 'the', 'ocean', 'waters', 'and', 'this', 'environment', 'that', 'we', 'live', 'in.']
# [on
# change]
# in.
# ["'Global", "warming'", 'is', 'a', 'myth', '—', 'so', 'say', '80', 'graphs', 'from', '58', 'peer-reviewed', 'scientific', 'papers', 'published', 'in', '2017.']
# 'global
# warming'
# a
# —
# 80
# 58
# peer-reviewed
# 2017.
# ['Neither', 'the', 'rate', 'nor', 'the', 'magnitude', 'of', 'the', 'reported', 'late', 'twentieth', 'century', 'surface', 'warming', '(1979–2000)', 'lay', 'outside', 'normal', 'natural', 'variability.']
# (1979–2000)
# variability.
# ['Forward', 'projections', 'of', 'solar', 'cyclicity', 'imply', 'the', 'next', 'few', 'decades', 'may', 'be', 'marked', 'by', 'global', 'cooling', 'rather', 'than', 'warming,', 'despite', 'continuing', 'CO2', 'emissions.']
# warming,
# co2
# emissions.
# ['global', 'warming', 'ceased', 'around', 'the', 'end', 'of', 'the', 'twentieth', 'century', 'and', 'was', 'followed', '(since', '1997)', 'by', '19', 'years', 'of', 'stable', 'temperature']
# (since
# 1997)
# 19
# ['Increases', 'in', 'atmospheric', 'CO2', 'followed', 'increases', 'in', 'temperature.']
# co2
# temperature.
# ['Therefore,', 'CO2', 'levels', 'could', 'not', 'have', 'forced', 'temperatures', 'to', 'rise.']
# therefore,
# co2
# rise.
# ['sea-level', 'rise', 'is', 'not', 'accelerating.']
# sea-level
# accelerating.
# ['Local', 'and', 'regional', 'sea', 'levels', 'continue', 'to', 'exhibit', 'typical', 'natural', 'variability—in', 'some', 'places', 'rising', 'and', 'in', 'others', 'falling.']
# variability—in
# falling.
# ['The', 'temperature', 'is', 'not', 'rising', 'nearly', 'as', 'fast', 'as', 'the', 'alarmist', 'computer', 'models', 'predicted.']
# predicted.
# ['more', 'than', '100', 'per', 'cent', 'of', 'the', 'warming', 'over', 'the', 'past', 'century', 'is', 'due', 'to', 'human', 'actions']
# 100
# ['90', 'per', 'cent', 'of', 'the', "world's", 'coral', 'reefs', 'will', 'disappear', 'in', 'the', 'next', '35', 'years', 'due', 'to', 'coral', 'bleaching', 'induced', 'by', 'global', 'warming,', 'pollution', 'and', 'over-development.']
# 90
# world's
# 35
# warming,
# over-development.
# ['the', 'warming', 'is', 'not', 'nearly', 'as', 'great', 'as', 'the', 'climate', 'change', 'computer', 'models', 'have', 'predicted.']
# predicted.
# ['El', 'Niño', 'drove', 'record', 'highs', 'in', 'global', 'temperatures', 'suggesting', 'rise', 'may', 'not', 'be', 'down', 'to', 'man-made', 'emissions.']
# man-made
# emissions.
# ['Increased', 'atmospheric', 'carbon', 'dioxide', 'has', 'helped', 'raise', 'global', 'food', 'production', 'and', 'reduce', 'poverty.']
# poverty.
# ['Sea', 'level', 'rise,', 'which', 'was', 'occurring', 'long', 'before', 'humans', 'could', 'be', 'blamed,', 'has', 'not', 'accelerated.']
# rise,
# blamed,
# accelerated.
# ['Sea', 'level', 'rise', 'could', 'reach', 'six', 'or', 'seven', 'feet', 'by', 'the', 'year', '2100.']
# 2100.
# ['Climate', 'change', 'is', 'not', 'making', 'natural', 'disasters', 'worse']
# ['The', 'amount', 'of', 'land', 'we', 'use', 'for', 'meat', '—', 'humankind’s', 'biggest', 'use', 'of', 'land', '—', 'has', 'declined', 'by', 'an', 'area', 'nearly', 'as', 'large', 'as', 'Alaska']
# —
# humankind’s
# —
# ['Carbon', 'emissions', 'are', 'declining', 'in', 'most', 'rich', 'nations', 'and', 'have', 'been', 'declining', 'in', 'Britain,', 'Germany,', 'and', 'France', 'since', 'the', 'mid-1970s']
# britain,
# germany,
# mid-1970s
# ['Preventing', 'future', 'pandemics', 'requires', 'more', 'not', 'less', '“industrial”', 'agriculture']
# “industrial”
# ['As', 'a', 'result,', 'half', 'of', 'the', 'people', 'surveyed', 'around', 'the', 'world', 'last', 'year', 'said', 'they', 'thought', 'climate', 'change', 'would', 'make', 'humanity', 'extinct.']
# a
# result,
# extinct.
# ['And', 'in', 'January,', 'one', 'out', 'of', 'five', 'British', 'children', 'told', 'pollsters', 'they', 'were', 'having', 'nightmares', 'about', 'climate', 'change.']
# january,
# change.
# ['Greenpeace', 'didn’t', 'save', 'the', 'whales,', 'switching', 'from', 'whale', 'oil', 'to', 'petroleum', 'and', 'palm', 'oil', 'did']
# didn’t
# whales,
# ['Worst-case', 'global', 'heating', 'scenarios', 'may', 'need', 'to', 'be', 'revised', 'upwards', 'in', 'light', 'of', 'a', 'better', 'understanding', 'of', 'the', 'role', 'of', 'clouds,', 'scientists', 'have', 'said.']
# worst-case
# a
# clouds,
# said.
# ['Recent', 'modelling', 'data', 'suggests', 'the', 'climate', 'is', 'considerably', 'more', 'sensitive', 'to', 'carbon', 'emissions', 'than', 'previously', 'believed']
# ['Previous', 'IPCC', 'reports', 'tended', 'to', 'assume', 'that', 'clouds', 'would', 'have', 'a', 'neutral', 'impact', 'because', 'the', 'warming', 'and', 'cooling', 'feedbacks', 'would', 'cancel', 'each', 'other', 'out.']
# a
# out.
# ['“Catherine', 'Senior,', 'head', 'of', 'understanding', 'climate', 'change', 'at', 'the', 'Met', 'Office', 'Hadley', 'Centre,', 'said', 'more', 'studies', 'and', 'more', 'data', 'were', 'needed', 'to', 'fully', 'understand', 'the', 'role', 'of', 'clouds', 'and', 'aerosols.']
# “catherine
# senior,
# centre,
# aerosols.
# ['Contemporary', 'Global', 'Warming', 'placed', 'in', 'geological', 'context.']
# context.
# ['Extreme', 'melting', 'and', 'changes', 'to', 'the', 'climate', 'like', 'this', 'has', 'released', 'pressure', 'on', 'to', 'the', 'continent,', 'allowing', 'the', 'ground', 'to', 'rise', 'up.']
# continent,
# up.
# ['We’ve', 'contacted', 'them', 'to', 'ask', 'more', 'details', 'about', 'the', 'size', 'of', 'the', 'Sif.']
# we’ve
# sif.
# ['Small', 'increases', 'in', 'average', 'temperature', 'translate', 'to', 'big', 'increases', 'in', 'the', 'number', 'of', 'extremely', 'hot', 'days,', 'and', 'those', 'hot', 'days', 'have', 'a', 'big', 'impact.']
# days,
# a
# impact.
# ['When', 'the', 'Emergency', 'Leaders', 'for', 'Climate', 'Action', 'approached', 'the', 'Federal', 'Government', 'in', 'April', 'they', 'were', 'drawing', 'on', 'decades', 'of', 'data', 'showing', 'that', 'fire', 'conditions', 'are', 'getting', 'worse.']
# worse.
# ['As', 'the', 'temperature', 'has', 'increased,', 'so', 'has', 'the', 'ability', 'of', 'scientists', 'to', 'determine', 'whether', 'specific', 'events', 'are', 'linked', 'to', 'climate', 'change.']
# increased,
# change.
# ['They', 'can', 'now', 'model', 'how', 'likely', 'a', 'specific', 'event', 'would', 'be', 'to', 'occur', 'under', 'historical', 'conditions,', 'compared', 'to', 'the', 'record', 'temperatures', 'we’re', 'experiencing.']
# a
# conditions,
# we’re
# experiencing.
# ['We’ll', 'still', 'be', 'facing', 'extreme', 'heat,', 'but', 'at', 'a', 'far', 'more', 'manageable', 'level', 'than', 'if', 'we’d', 'done', 'nothing', 'to', 'halt', 'climate', 'change.']
# we’ll
# heat,
# a
# we’d
# change.
# ['If', 'there', 'were', '[carbon', 'emissions],', 'we', 'could', 'not', 'see', 'because', 'most', 'carbon', 'is', 'black.']
# [carbon
# emissions],
# black.
# ['Reef', 'material', 'is', 'calcium', 'carbonate,', 'which', 'contains', '44', 'per', 'cent', 'carbon', 'dioxide.']
# carbonate,
# 44
# dioxide.
# ['Reefs', 'need', 'carbon', 'dioxide;', 'it’s', 'their', 'basic', 'food.']
# dioxide;
# it’s
# food.
# ['It', 'has', 'never', 'been', 'shown', 'that', 'human', 'emissions', 'of', 'carbon', 'dioxide', 'drive', 'global', 'warming.']
# warming.
# ['Modellers', 'assume', 'carbon', 'dioxide', 'drives', 'climate', 'change']
# ['The', 'geological', 'history', 'of', 'the', 'planet', 'shows', 'major', 'planetary', 'climate', 'changes', 'have', 'never', 'been', 'driven', 'by', 'a', 'trace', 'gas']
# a
# ['Climate', 'change', 'is', 'normal', 'and', 'continual.']
# continual.
# ['The', 'main', 'greenhouse', 'gas', 'is', 'water', 'vapour[…]']
# vapour[…]
# ['Carbon', 'dioxide', 'is', 'a', 'non-condensable', 'atmospheric', 'gas', 'like', 'nitrogen', 'and', 'oxygen']
# a
# non-condensable
# ['Without', 'carbon', 'dioxide,', 'all', 'life', 'on', 'Earth', 'would', 'die']
# dioxide,
# ['Plants', 'need', 'almost', 'three', 'times', 'today’s', 'carbon', 'dioxide', 'content', 'of', 'the', 'atmosphere', 'to', 'thrive.']
# today’s
# thrive.
# ['For', 'decades', 'horticulturalists', 'have', 'pumped', 'carbon', 'dioxide', 'into', 'glasshouses', 'to', 'increase', 'yields.']
# horticulturalists
# yields.
# ['In', 'the', 'past,', 'warming', 'has', 'never', 'been', 'a', 'threat', 'to', 'life', 'on', 'Earth.']
# past,
# a
# earth.
# ['if', 'we', 'halved', 'today’s', 'atmospheric', 'carbon', 'dioxide', 'content,', 'all', 'life', 'would', 'die.']
# today’s
# content,
# die.
# ['In', 'our', 'lifetime,', 'there', 'has', 'been', 'no', 'correlation', 'between', 'carbon', 'dioxide', 'emissions', 'and', 'temperature']
# lifetime,
# ['after', 'a', 'natural', 'orbitally', 'driven', 'warming,', 'atmospheric', 'carbon', 'dioxide', 'content', 'increases', '800', 'years', 'later']
# a
# warming,
# 800
# ['Each', 'of', 'the', 'six', 'major', 'past', 'ice', 'ages', 'began', 'when', 'the', 'atmospheric', 'carbon', 'dioxide', 'content', 'was', 'far', 'higher', 'than', 'at', 'present.']
# present.
# ['For', 'decades,', 'most', 'scientists', 'saw', 'climate', 'change', 'as', 'a', 'distant', 'prospect.']
# decades,
# a
# prospect.
# ['A', 'recent', 'essay', 'in', 'Scientific', 'American', 'argued', 'that', 'scientists', '“tend', 'to', 'underestimate', 'the', 'severity', 'of', 'threats', 'and', 'the', 'rapidity', 'with', 'which', 'they', 'might', 'unfold”', 'and', 'said', 'one', 'of', 'the', 'reasons', 'was', '“the', 'perceived', 'need', 'for', 'consensus.”']
# a
# “tend
# unfold”
# “the
# consensus.”
# ['[The', '1990', 'IPCC', 'report', 'said]', 'that', 'the', 'Antarctic', 'ice', 'sheets', 'were', 'stable']
# [the
# 1990
# said]
# ['Hurricane', 'Harvey', 'gave', 'Houston', 'and', 'the', 'surrounding', 'region', 'a', '$125', 'billion', 'lesson', 'about', 'the', 'costs', 'of', 'misjudging', 'the', 'potential', 'for', 'floods']
# a
# $125
# ['In', 'the', 'early', '2000s,', 'ice', 'shelves', 'began', 'disintegrating', 'in', 'several', 'parts', 'of', 'Antarctica,', 'and', 'scientists', 'realized', 'that', 'process', 'could', 'greatly', 'accelerate', 'the', 'demise', 'of', 'the', 'vastly', 'larger', 'ice', 'sheets', 'themselves.']
# 2000s,
# antarctica,
# themselves.
# ['The', 'planet’s', 'average', 'ground', 'temperature', 'has', 'risen', 'by', 'around', '1.62F', '(0.9C)']
# planet’s
# 1.62f
# (0.9c)
# ['global', 'temperatures', 'have', 'risen', 'between', '0.23F', '(0.13C)', 'and', '0.34F', '(0.19C)', 'per', 'decade']
# 0.23f
# (0.13c)
# 0.34f
# (0.19c)
# ['However', 'the', 'warming', 'trend', 'is', 'slower', 'than', 'most', 'climate', 'models', 'have', 'forecast']
# ['In', '1990', 'the', 'United', 'Nation’s', 'Intergovernmental', 'Panel', 'on', 'Climate', 'Change', '(IPCC)', 'predicted', 'that', 'temperatures', 'would', 'rise', 'by', '0.54F', '(0.3C)', 'per', 'decade.']
# 1990
# nation’s
# intergovernmental
# (ipcc)
# 0.54f
# (0.3c)
# decade.
# ['In', 'its', '5th', 'assessment', 'report', 'in', '2013,', 'the', 'IPCC', 'estimated', 'that', 'human', 'emissions', 'are', 'probably', 'responsible', 'for', 'more', 'than', 'half', 'of', 'the', 'observed', 'increase', 'in', 'global', 'average', 'temperature', 'from', '1951', 'to', '2010.']
# 5th
# 2013,
# 1951
# 2010.
# ['But', 'it', 'means', 'a', 'chunk', 'of', 'the', 'rise', 'is', 'coming', 'from', 'elsewhere.']
# a
# elsewhere.
# ['at', 'the', 'end', 'of', 'recent', 'ice', 'ages,', 'the', 'concentration', 'of', 'carbon', 'dioxide', 'in', 'the', 'atmosphere', 'started', 'to', 'rise', 'only', 'after', 'temperatures', 'began', 'to', 'climb.']
# ages,
# climb.
# ['But', 'by', 'far', 'the', 'largest', 'greenhouse', 'gas', 'is', 'water', 'vapour,', 'which', 'makes', '95', 'per', 'cent', 'of', 'the', 'total.']
# vapour,
# 95
# total.
# ['CO2', 'is', 'not', 'powerful', 'in', 'that', 'sense,', 'the', 'only', 'thing', 'it', 'does', 'in', 'the', 'system', 'is', 'make', 'the', 'planet', 'greener.']
# co2
# sense,
# greener.
# ['it’s', 'virtually', 'impossible', 'to', 'get', 'funded', 'for', 'work', 'that', 'disputes', 'climate', 'change', 'through', 'other', 'channels', '[other', 'than', 'oil', 'companies]']
# it’s
# [other
# companies]
# ['One', 'of', 'the', 'main', 'areas', 'of', 'contention', 'is', 'the', 'existence', 'of', 'two', 'strange', 'climate', 'episodes', 'known', 'as', 'The', 'Medieval', 'Warm', 'Period', '(MWP)', 'and', 'the', 'Little', 'Ice', 'Age.']
# (mwp)
# age.
# ['The', 'MWP', 'lasted', 'from', 'about', '950', 'to', '1250AD,', 'and', 'temperature', 'records', 'appear', 'to', 'show', 'it', 'was', 'even', 'hotter', 'than', 'today']
# 950
# 1250ad,
# ['But', 'the', 'period', 'has', 'caused', 'a', 'headache', 'for', 'climate', 'scientists', 'because', 'clearly', 'there', 'was', 'no', 'upswell', 'in', 'carbon', 'dioxide', 'that', 'could', 'account', 'for', 'such', 'swift', 'warming.']
# a
# warming.
# ['in', '1995', 'one', 'scientist', 'at', 'the', 'IPCC', '–', 'Jonathan', 'Overpeck', '–', 'wrote', 'an', 'email', 'to', 'a', 'colleague', 'claiming', '‘we', 'have', 'to', 'get', 'rid', 'of', 'the', 'Medieval', 'Warm', 'Period.’']
# 1995
# –
# –
# a
# ‘we
# period.’
# ['it', 'later', 'emerged', 'that', 'its', 'creator', 'Dr', 'Michael', 'Mann', 'had', 'spliced', 'too', '[sic]', 'datasets', 'together', '–', 'tree-rings', 'showing', 'temperatures', 'going', 'back', 'hundreds', 'of', 'years,', 'then', 'recent', 'thermometer', 'readings', 'for', 'the', 'more', 'recent', 'decades.']
# [sic]
# –
# tree-rings
# years,
# decades.
# ['The', 'IPCC', 'no', 'longer', 'includes', 'the', '‘Hockey', 'stick’', 'chart', 'in', 'its', 'reports.']
# ‘hockey
# stick’
# reports.
# ['Yet', 'a', 'study', 'published', 'just', 'this', 'week,', 'by', 'the', 'Bjerknes', 'Centre', 'for', 'Climate', 'Research', 'in', 'Bergen,', 'Norway,', 'found', 'that', 'the', 'natural', 'climate', 'system', 'can', 'change', 'abruptly,', 'without', 'the', 'need', 'for', 'any', 'external', 'forces.']
# a
# week,
# bergen,
# norway,
# abruptly,
# forces.
# ['Some', 'scientists', 'believe', 'that', 'solar', 'activity', 'is', 'more', 'likely', 'to', 'influence', 'today’s', 'climate', 'than', 'carbon', 'dioxide,', 'and', 'Dr', 'Soon', 'has', 'compiled', 'data', 'showing', 'temperature', 'in', 'America,', 'Canada', 'and', 'Mexico', 'rises', 'and', 'falls', 'in', 'line', 'with', 'solar', 'activity.']
# today’s
# dioxide,
# america,
# activity.
# ['The', 'melting', 'ice', 'has', 'led', 'to', 'global', 'sea', 'level', 'rise', 'of', 'around', 'eight', 'inches', 'since', 'reliable', 'record', 'keeping', 'began', 'in', '1880.']
# 1880.
# ['until', 'temperature', 'increases', 'began', 'to', 'slow', 'down', 'after', '1998', 'and', 'remained', 'relatively', 'stable', 'for', 'a', 'period', 'of', '15', 'years']
# 1998
# a
# 15
# ['In', 'one', 'particularly', 'damning', 'email,', 'CRU', 'director', 'Phil', 'Jones', 'said', 'he', 'had', 'used', '‘Mike’s', 'Nature', 'trick’', 'to', '‘hide', 'the', 'decline’', 'in', 'temperatures', 'in', 'the', 'second', 'half', 'of', 'the', '20th', 'century.']
# email,
# ‘mike’s
# trick’
# ‘hide
# decline’
# 20th
# century.
# ['In', 'an', 'interview', 'with', 'the', 'BBC', 'after', 'the', 'scandal', 'broke,', 'Dr', 'Jones', 'admitted', 'there', 'had', 'been', 'no', 'statistically', 'significant', 'global', 'warming', 'since', '1995']
# broke,
# 1995
# ['The', 'panel', 'was', 'forced', 'to', 'retract', 'a', 'statement', 'in', 'its', '2007', 'report', 'saying', 'all', 'Himalayan', 'glaciers', 'could', 'melt', 'entirely', 'by', '2035.']
# a
# 2007
# 2035.
# ['The', 'figure', 'traditionally', 'cited', 'that', 'suggests', '97', 'per', 'cent', 'of', 'climate', 'scientists', 'agree', 'that', 'global', 'warming', 'is', 'man-made', 'was', 'also', 'found', 'to', 'be', 'flawed.']
# 97
# man-made
# flawed.
# ['Climate', 'skeptics', 'argue', 'temperature', 'records', 'have', 'been', 'adjusted', 'in', 'recent', 'years', 'to', 'make', 'the', 'past', 'appear', 'cooler', 'and', 'the', 'present', 'warmer,', 'although', 'the', 'Carbon', 'Brief', 'showed', 'that', 'NOAA', 'has', 'actually', 'made', 'the', 'past', 'warmer,', 'evening', 'out', 'the', 'difference.']
# warmer,
# warmer,
# difference.
# ['When', 'the', 'measuring', 'equipment', 'gets', 'old', 'and', 'needs', 'replacing,', 'it', 'often', 'requires', 're-calibration.']
# replacing,
# re-calibration.
# ['A', 'global', 'network', 'of', '500', 'scientists', 'and', 'professionals', 'has', 'prepared', 'this', 'urgent', 'message.']
# a
# 500
# message.
# ['The', 'Little', 'Ice', 'Age', 'ended', 'as', 'recently', 'as', '1850.']
# 1850.
# ['Only', 'very', 'few', 'peer-reviewed', 'papers', 'even', 'go', 'so', 'far', 'as', 'to', 'say', 'that', 'recent', 'warming', 'is', 'chiefly', 'anthropogenic.']
# peer-reviewed
# anthropogenic.
# ['In', 'addition,', '[climate', 'models]', 'ignore', 'the', 'fact', 'that', 'enriching', 'the', 'atmosphere', 'with', 'CO2', 'is', 'beneficial']
# addition,
# [climate
# models]
# co2
# ['There', 'is', 'no', 'statistical', 'evidence', 'that', 'global', 'warming', 'is', 'intensifying[…]', 'floods']
# intensifying[…]
# ['There', 'is', 'no', 'statistical', 'evidence', 'that', 'global', 'warming', 'is', 'intensifying[…]', 'droughts']
# intensifying[…]
# ['For', 'instance,', 'wind', 'turbines', 'kill', 'birds', 'and', 'insects,', 'and', 'palm-oil', 'plantations', 'destroy', 'the', 'biodiversity', 'of', 'the', 'rainforests']
# instance,
# insects,
# palm-oil
# ['[data]', 'show', 'only', 'slight', 'warming,', 'mostly', 'at', 'night', 'and', 'in', 'winter']
# [data]
# warming,
# ['there', 'has', 'been', 'no', 'systematic', 'increase', 'in', 'the', 'frequency', 'of', 'extreme', 'weather', 'events,']
# events,
# ['Let’s', 'find', 'out', 'by', 'comparing', 'the', 'actual', 'temperatures', 'since', '1979', 'with', 'what', 'the', '32', 'families', 'of', 'climate', 'models', 'used', 'in', 'the', 'latest', 'U.N.', 'report', 'on', 'climate', 'science', 'predicted', 'they', 'would', 'be.']
# let’s
# 1979
# 32
# u.n.
# be.
# ['the', 'models', 'predicted', 'seven', 'times', 'as', 'much', 'warming', 'as', 'has', 'been', 'observed']
# ['Most', 'of', 'the', 'atmospheric', 'moisture', 'originates', 'in', 'the', 'tropical', 'ocean,', 'and', 'the', 'difference', 'between', 'surface', 'and', 'upper', 'atmospheric', 'temperature', 'determines', 'how', 'much', 'of', 'the', 'moisture', 'rises', 'into', 'the', 'atmosphere.']
# ocean,
# atmosphere.
# ['Globally', 'averaged', 'thermometers', 'show', 'two', 'periods', 'of', 'warming', 'since', '1900:', 'a', 'half-degree', 'from', 'natural', 'causes', 'in', 'the', 'first', 'half', 'of', 'the', '20th', 'century,', 'before', 'there', 'was', 'an', 'increase', 'in', 'industrial', 'carbon', 'dioxide', 'that', 'was', 'enough', 'to', 'produce', 'it,', 'and', 'another', 'half-degree', 'in', 'the', 'last', 'quarter', 'of', 'the', 'century.']
# 1900:
# a
# half-degree
# 20th
# century,
# it,
# half-degree
# century.
# ['The', 'first', 'adjustment', 'changed', 'how', 'the', 'temperature', 'of', 'the', 'ocean', 'surface', 'is', 'calculated,', 'by', 'replacing', 'satellite', 'data', 'with', 'drifting', 'buoys', 'and', 'temperatures', 'in', 'ships’', 'water', 'intake.']
# calculated,
# ships’
# intake.
# ['But', 'each', 'serial', 'adjustment', 'has', 'tended', 'to', 'make', 'the', 'early', 'years', 'colder,', 'which', 'increases', 'the', 'warming', 'trend.']
# colder,
# trend.
# ['Shelters', 'in', 'poorer', 'countries', 'are', 'not', 'repainted', 'as', 'often,', 'and', 'darker', 'stations', 'absorb', 'more', 'of', 'the', 'sun’s', 'energy.']
# often,
# sun’s
# energy.
# ['Last', 'month', 'was', 'the', 'hottest', 'June', 'ever', 'recorded,', 'European', 'satellite', 'agency', 'announces']
# recorded,
# ['temperatures', 'were', '6-10C', 'above', 'normal', 'over', 'most', 'of', 'France,', 'Germany', 'and', 'northern', 'Spain', 'during', 'the', 'final', 'days', 'of', 'the', 'month,', 'according', 'to', 'C3S.']
# 6-10c
# france,
# month,
# c3s.
# ['Rapid', 'assessment', 'of', 'average', 'temperatures', 'in', 'France', 'between', '26-28', 'June', 'showed', 'a', '“substantial”', 'increase', 'in', 'the', 'likelihood', 'of', 'the', 'heatwave', 'happening', 'as', 'a', 'result', 'of', 'human-caused', 'global', 'warming,', 'experts', 'at', 'the', 'World', 'Weather', 'Attribution', 'group', 'said.']
# 26-28
# a
# “substantial”
# a
# human-caused
# warming,
# said.
# ['Heatwaves', 'occur', 'in', 'any', 'climate,', 'but', 'we', 'know', 'that', 'heatwaves', 'are', 'becoming', 'much', 'more', 'likely', 'due', 'to', 'climate', 'change.']
# climate,
# change.
# ['While', 'members', 'of', 'the', 'media', 'may', 'nod', 'along', 'to', 'such', 'claims', '[about', 'changes', 'in', 'weather', 'extremes],', 'the', 'evidence', 'paints', 'a', 'different', 'story']
# [about
# extremes],
# a
# ['They', 'concluded', 'that', 'trends', 'toward', 'rising', 'climate', 'damages', 'were', 'mainly', 'due', 'to', 'increased', 'population', 'and', 'economic', 'activity', 'in', 'the', 'path', 'of', 'storms,', 'that', 'it', 'was', 'not', 'currently', 'possible', 'to', 'determine', 'the', 'portion', 'of', 'damages', 'attributable', 'to', 'greenhouse', 'gases,', 'and', 'that', 'they', 'didn’t', 'expect', 'that', 'situation', 'to', 'change', 'in', 'the', 'near', 'future.']
# storms,
# gases,
# didn’t
# future.
# ['Globally', 'there’s', 'no', 'clear', 'evidence', 'of', 'trends', 'and', 'patterns', 'in', 'extreme', 'events', 'such', 'as', 'droughts,', 'hurricanes', 'and', 'floods.']
# there’s
# droughts,
# floods.
# ['There’s', 'no', 'trend', 'in', 'hurricane-related', 'flooding', 'in', 'the', 'U.S.']
# there’s
# hurricane-related
# u.s.
# ['Nor', 'is', 'there', 'evidence', 'of', 'an', 'increase', 'in', 'floods', 'globally.']
# globally.
# ['Since', '1965,', 'more', 'parts', 'of', 'the', 'U.S.', 'have', 'seen', 'a', 'decrease', 'in', 'flooding', 'than', 'have', 'seen', 'an', 'increase.']
# 1965,
# u.s.
# a
# increase.
# ['And', 'from', '1940', 'to', 'today,', 'flood', 'damage', 'as', 'a', 'percentage', 'of', 'GDP', 'has', 'fallen', 'to', 'less', 'than', '0.05', 'per', 'cent', 'per', 'year', 'from', 'about', '0.2', 'per', 'cent.']
# 1940
# today,
# a
# 0.05
# 0.2
# cent.
# ['The', 'bottom', 'line', 'is', 'there’s', 'no', 'solid', 'connection', 'between', 'climate', 'change', 'and', 'the', 'major', 'indicators', 'of', 'extreme', 'weather']
# there’s
# ['This', 'requires', 'us', 'to', 'work', 'towards', 'avoiding', 'catastrophic', 'possibilities', 'rather', 'than', 'looking', 'at', 'probabilities,', 'as', 'learning', 'from', 'mistakes', 'is', 'not', 'an', 'option', 'when', 'it', 'comes', 'to', 'existential', 'risks.']
# probabilities,
# risks.
# ['With', 'that', 'in', 'mind,', 'they', 'propose', 'a', 'plausible', 'and', 'terrifying', '“2050', 'scenario”', 'whereby', 'humanity', 'could', 'face', 'irreversible', 'collapse', 'in', 'just', 'three', 'decades.']
# mind,
# a
# “2050
# scenario”
# decades.
# ['Their', 'analysis', 'calculates', 'the', 'existential', 'climate-related', 'security', 'risk', 'to', 'Earth', 'through', 'a', 'scenario', 'set', '30', 'years', 'into', 'the', 'future.']
# climate-related
# a
# 30
# future.
# ['North', 'America', 'suffers', 'extreme', 'weather', 'events', 'including', 'wildfires,', 'drought,', 'and', 'heatwaves.']
# wildfires,
# drought,
# heatwaves.
# ['Monsoons', 'in', 'China', 'fail,', 'the', 'great', 'rivers', 'of', 'Asia', 'virtually', 'dry', 'up,', 'and', 'rainfall', 'in', 'central', 'America', 'falls', 'by', 'half.']
# fail,
# up,
# half.
# ['The', 'knock-on', 'consequences', 'affect', 'national', 'security,', 'as', 'the', 'scale', 'of', 'the', 'challenges', 'involved,', 'such', 'as', 'pandemic', 'disease', 'outbreaks,', 'are', 'overwhelming.']
# knock-on
# security,
# involved,
# outbreaks,
# overwhelming.
# ['Armed', 'conflicts', 'over', 'resources', 'may', 'become', 'a', 'reality,', 'and', 'have', 'the', 'potential', 'to', 'escalate', 'into', 'nuclear', 'war.']
# a
# reality,
# war.
# ['The', 'most', 'recent', 'IPCC', 'report', 'lays', 'out', 'a', 'future', 'if', 'we', 'limit', 'global', 'heating', 'to', '1.5°C', 'instead', 'of', 'the', 'Paris', 'Agreement’s', '2°C.']
# a
# 1.5°c
# agreement’s
# 2°c.
# ['By', '2050', 'there’s', 'a', 'scientific', 'consensus', 'that', 'we', 'reached', 'the', 'tipping', 'point', 'for', 'ice', 'sheets', 'in', 'Greenland', 'and', 'the', 'West', 'Antarctic']
# 2050
# there’s
# a
# ['Like', 'countless', 'other', 'organ\xadisms,', 'we', 'move', 'and', 'adapt', 'when', 'the', 'environment', 'changes.']
# organ­isms,
# changes.
# ['when', '3', 'per', 'cent', 'of', 'total', 'annual', 'global', 'emissions', 'of', 'carbon', 'dioxide', 'are', 'from', 'humans', 'and', 'Australia', 'prod\xaduces', '1.3', 'per', 'cent', 'of', 'this', '3', 'per', 'cent,', 'then', 'no', 'amount', 'of', 'emissions', 'reductio\xadn', 'here', 'will', 'have', 'any', 'effect', 'on', 'global', 'climate.']
# 3
# prod­uces
# 1.3
# 3
# cent,
# reductio­n
# climate.
# ['whenever', 'in', 'the', 'past', 'there', 'was', 'an', 'explosion', 'of', 'plant', 'life,', 'the', 'carbon', 'dioxide', 'content', 'was', 'far', 'higher', 'than', 'at', 'present.']
# life,
# present.
# ['If', 'we', 'halve', 'the', 'carbon', 'dioxide', 'content', 'of', 'the', 'atmosphere,', 'all', 'life', 'dies.']
# atmosphere,
# dies.
# ['for', 'thousands', 'of', 'millions', 'of', 'years', 'the', 'Earth', 'has', 'been', 'changing,', 'with', 'cycles\xad', 'and', 'one-off', 'events', 'such', 'as', 'an', 'asteroid', 'impact,', 'super-volcano', 'or', 'a', 'supernova', 'explosion.']
# changing,
# cycles­
# one-off
# impact,
# super-volcano
# a
# explosion.
# ['[subsidies', 'for', 'wind', 'and', 'solar]', 'add', 'to', 'emissions', 'because', 'coal-fired', 'elec\xadtricity', 'needs', 'to', 'be', 'on', 'standby', 'for', 'when', 'there', 'is', 'no', 'wind', 'or', 'sunshine.']
# [subsidies
# solar]
# coal-fired
# elec­tricity
# sunshine.
# ['The', 'amount', 'of', 'energy', 'used', 'to', 'construct', 'solar', 'and', 'wind', 'facilities', 'is', 'greater', 'than', 'they', 'produce', 'in', 'their', 'working', 'lives.']
# lives.
# ['“As', 'soon', 'as', 'renewables', 'were', 'introduced', 'into', 'the', 'grid,', 'electric\xadity', 'prices', 'increased', 'and', 'delivery', 'became', 'unreliable.']
# “as
# grid,
# electric­ity
# unreliable.
# ['Renew\xadables', 'such', 'as', 'wind', 'turbines', 'are', 'environmentally', 'disastrous', 'because', 'they', 'pollute', 'a', 'huge', 'land', 'area,', 'slice', 'and', 'dice', 'birds', 'and', 'bats,', 'kill', 'insects', 'that', 'are', 'bird', 'food,', 'create', 'health', 'problems', 'for', 'humans', 'who', 'live', 'within', 'kilometres', 'of', 'them,', 'leave', 'toxins', 'around', 'the', 'turbine', 'site', 'and', 'despoil', 'the', 'landscape.']
# renew­ables
# a
# area,
# bats,
# food,
# them,
# landscape.
# ['We', 'have', 'also', 'been', 'told', 'the', 'problem', 'is', 'DEFINITELY', 'NOT', 'a', 'billions-year-old', 'planet', 'running', 'through', 'cycles', 'where', 'the', 'temperature', 'might', 'fluctuate', 'a', 'bit.']
# a
# billions-year-old
# a
# bit.
# ['there', 'were', 'no', 'ice', 'sheets', 'covering', 'either', 'Greenland', 'or', 'West', 'Antarctica,', 'and', 'much', 'of', 'the', 'East', 'Antarctic', 'ice', 'sheet', 'was', 'gone.']
# antarctica,
# gone.
# ['a', 'study', 'that', 'totally', 'debunks', 'the', 'whole', 'concept', 'of', 'man-made', 'Global', 'Warming']
# a
# man-made
# ['nothing', 'we', 'can', 'do', 'to', 'stop', 'the', 'Earth’s', 'naturally', 'occurring', 'climate', 'cycles.']
# earth’s
# cycles.
# ['Climate', 'Change', '‘Heat', 'Records’', 'Are', 'a', 'Huge', 'Data', 'Manipulation']
# ‘heat
# records’
# a
# ['The', 'idea', 'that', 'climate', 'change', 'is', 'producing', 'heat', 'records', 'across', 'the', 'Earth', 'is', 'among', 'the', 'most', 'egregious', 'manipulations', 'of', 'data', 'in', 'the', 'absurd', 'global', 'warming', 'debate.']
# debate.
# ['On', 'Feb.', '7,', 'several', 'major', 'newspapers', 'carried', 'stories', 'of', 'the', 'declaration', 'by', 'NASA', 'and', 'NOAA', 'that', 'the', 'past', 'five', 'years', 'have', 'been', 'the', 'warmest', 'on', 'record.']
# feb.
# 7,
# record.
# ['Actual', 'weather', 'records', 'over', 'the', 'past', '100', 'years', 'show', 'no', 'correlation', 'between', 'rising', 'carbon', 'dioxide', 'levels', 'and', 'local', 'temperatures.']
# 100
# temperatures.
# ['as', 'time', 'progresses', 'and', 'fossil', 'fuel', 'emissions', 'increase,', 'the', 'number', 'of', 'record', 'highs', 'should', 'increase', 'and', 'record', 'lows', 'should', 'decrease.']
# increase,
# decrease.
# ['From', '1970', 'until', '1998', 'there', 'was', 'a', 'warming', 'period', 'that', 'raised', 'temperatures', 'by', 'about', '0.7', 'F', 'that', 'helped', 'spawn', 'the', 'global', 'warming', 'alarmist', 'movement.']
# 1970
# 1998
# a
# 0.7
# f
# movement.
# ['However,', 'since', '1998,', 'little', 'warming', 'has', 'occurred', 'while', 'carbon', 'dioxide', 'emissions', 'continue', 'to', 'increase.']
# however,
# 1998,
# increase.
# ['describes', 'a', 'world', 'of', 'worsening', 'food', 'shortages', 'and', 'wildfires,', 'and', 'a', 'mass', 'die-off', 'of', 'coral', 'reefs', 'as', 'soon', 'as', '2040']
# a
# wildfires,
# a
# die-off
# 2040
# ['But', 'the', 'heads', 'of', 'small', 'island', 'nations,', 'fearful', 'of', 'rising', 'sea', 'levels,', 'had', 'also', 'asked', 'scientists', 'to', 'examine', 'the', 'effects', 'of', '2.7', 'degrees', 'of', 'warming.']
# nations,
# levels,
# 2.7
# warming.
# ['International', 'Energy', 'Agency,', 'a', 'global', 'analysis', 'organization,', '“continue', 'to', 'see', 'a', 'role', 'for', 'coal', 'for', 'the', 'foreseeable', 'future.”']
# agency,
# a
# organization,
# “continue
# a
# future.”
# ['Duffy', 'pointed', 'out', 'that', 'his', 'chart', 'was', 'from', 'a', 'single', 'tide', 'gauge', 'station,', 'near', 'San', 'Francisco,', 'and', 'that', 'sea', 'levels', 'rise', 'at', 'different', 'rates', 'around', 'the', 'world']
# a
# station,
# francisco,
# ['Brooks', 'added', 'that', 'Antarctic', 'ice', 'is', 'growing.']
# growing.
# ['“But', 'there', 'are', 'plenty', 'of', 'studies', 'that', 'have', 'come', 'that', 'show', 'with', 'respect', 'to', 'Antarctica', 'that', 'the', 'total', 'ice', 'sheet,', 'particularly', 'that', 'above', 'land,', 'is', 'increasing,', 'not', 'decreasing.']
# “but
# sheet,
# land,
# increasing,
# decreasing.
# ['Climate', 'scientists', 'use', 'the', '20th-century', 'average', 'as', 'a', 'benchmark', 'for', 'global', 'temperature', 'measurements.']
# 20th-century
# a
# measurements.
# ['It’s', 'also', 'a', 'sufficiently', 'long', 'period', 'to', 'include', 'several', 'cycles', 'of', 'climate', 'variability.']
# it’s
# a
# variability.
# ['NOAA’s', 'analysis', 'found', 'last', 'month', 'was', 'the', '3rd-warmest', 'April', 'on', 'record', 'globally.']
# noaa’s
# 3rd-warmest
# globally.
# ['The', 'unusual', 'heat', 'was', 'most', 'noteworthy', 'in', 'Europe,', 'which', 'had', 'its', 'warmest', 'April', 'on', 'record,', 'and', 'Australia,', 'which', 'had', 'its', 'second-warmest.']
# europe,
# record,
# australia,
# second-warmest.
# ['For', 'the', 'year-to-date,', 'the', 'Earth', 'is', 'seeing', 'its', '5th-warmest', 'start', 'to', 'the', 'year.']
# year-to-date,
# 5th-warmest
# year.
# ['There', 'is', 'no', 'empirical', 'evidence', 'that', 'increasing', 'greenhouse', 'gases', 'are', 'the', 'primary', 'cause', 'of', 'Global', 'Warming']
# ['“Today', 'climate', 'scientists', 'are', 'obsessed', 'with', 'the', 'level', 'of', 'carbon', 'dioxide', 'in', 'the', 'atmosphere,', 'a', 'very', 'very', 'small', 'part', 'of', 'the', 'overall', 'picture.']
# “today
# atmosphere,
# a
# picture.
# ['Carbon', 'dioxide', 'is', 'a', 'trace', 'gas.”']
# a
# gas.”
# ['It’s', 'not', 'carbon', 'dioxide,', 'it’s', 'not', 'methane…', 'Scientists', 'estimate', 'that', 'somewhere', 'between', '75%', 'and', '90%', 'of', 'Earth', 'greenhouse', 'effect', 'is', 'caused', 'by', 'water', 'vapor', 'in', 'clouds.”']
# it’s
# dioxide,
# it’s
# methane…
# 75%
# 90%
# clouds.”
# ['“Every', 'day,', 'nature', 'puts', 'twenty', 'times', 'as', 'much', 'carbon', 'dioxide', 'into', 'the', 'atmosphere', 'as', 'all', 'of', 'Earth', 'industries.']
# “every
# day,
# industries.
# ['So', 'it’s', 'clear', 'now', 'we’re', 'not', 'seeing', 'dangerous', 'global', 'warming,', 'and', 'the', 'climate', 'models', 'are', 'wrong.']
# it’s
# we’re
# warming,
# wrong.
# ['If', 'we', 'double', 'atmospheric', 'carbon', 'dioxide[…]', 'we’d', 'only', 'raise', 'global', 'surface', 'temperatures', 'by', 'about', 'a', 'degree', 'Celsius.']
# dioxide[…]
# we’d
# a
# celsius.
# ['The', 'idea', 'that', 'the', 'much', 'smaller', 'carbon', 'dioxide', 'cycle', 'is', 'now', 'controlling', 'the', 'water', 'cycle', 'is', 'not', 'very', 'likely.']
# likely.
# ['“So', 'the', 'bottom', 'line', 'of', 'all', 'this', 'is', 'that', 'climate', 'change', 'is', 'natural,', 'not', 'man-made.']
# “so
# natural,
# man-made.
# ['Man-made', 'greenhouse', 'gases', 'play', 'only', 'an', 'insignificant', 'role.”']
# man-made
# role.”
# ['Climate', 'scientists', 'are', 'telling', 'us', 'it’s', 'likely', 'we’re', 'going', 'to', 'be', 'in', 'for', 'a', 'period', 'of', 'cooling.']
# it’s
# we’re
# a
# cooling.
# ['temperatures', 'rise', 'and', 'they', 'fall,', 'and', 'they', 'rise', 'and', 'they', 'fall…', 'and', 'for', 'the', 'last', '400', 'years', 'we’ve', 'had', 'a', 'gentle', 'warming', 'as', 'we’ve', 'been', 'coming', 'out', 'of', 'the', 'little', 'ice', 'age.']
# fall,
# fall…
# 400
# we’ve
# a
# we’ve
# age.
# ['Temperatures', 'cooled', 'from', 'about', '1940', 'to', '1975,', 'and', 'then', 'they', 'rose', 'from', 'about', '’75', 'to', 'about', '2005', 'or', 'so,', 'and', 'since', 'then', 'they’ve', 'been', 'flat', 'or', 'cooling.']
# 1940
# 1975,
# ’75
# 2005
# so,
# they’ve
# cooling.
# ['“So', 'now', 'we’re', 'able', 'to', 'explain', 'from', 'natural', 'factors', 'how', 'we’ve', 'had', 'the', '20th', 'Century', 'warming.']
# “so
# we’re
# we’ve
# 20th
# warming.
# ['This', 'is', 'the', 'South', 'Pole', 'ice,', '90%', 'of', 'Earth’s', 'ice,', 'and', 'it’s', 'getting', 'thicker.']
# ice,
# 90%
# earth’s
# ice,
# it’s
# thicker.
# ['Ocean', 'levels', 'have', 'been', 'rising', 'for', 'the', 'last', '20,000', 'years[…]', 'No', 'climate', 'scientist', 'can', 'tell', 'you', 'when', 'natural', 'sea', 'level', 'rise', 'stopped', 'and', 'man-made', 'sea', 'level', 'rise', 'began.']
# 20,000
# years[…]
# man-made
# began.
# ['According', 'to', 'NASA,', 'the', 'globally', 'averaged', 'temperature', 'of', 'the', 'land', 'and', 'ocean', 'was', '0.9˚C', '(1.62˚F)', 'above', 'the', '20th', 'century', 'average.']
# nasa,
# 0.9˚c
# (1.62˚f)
# 20th
# average.
# ['La', 'Niñas,', 'on', 'the', 'other', 'hand,', 'feature', 'cooler', 'than', 'average', 'waters', 'in', 'the', 'Pacific']
# niñas,
# hand,
# ['Sea', 'ice', 'continued', 'its', 'declining', 'trend,', 'both', 'in', 'the', 'Arctic', 'and', 'Antarctic.']
# trend,
# antarctic.
# ['Scientists', 'say', 'halting', 'deforestation', '‘just', 'as', 'urgent’', 'as', 'reducing', 'emissions']
# ‘just
# urgent’
# ['Protecting', 'and', 'restoring', 'forests', 'would', 'reduce', '18%', 'of', 'emissions', 'by', '2030']
# 18%
# 2030
# ['It', 'is', 'expected', 'the', 'report', 'will', 'focus', 'on', 'required', 'changes', 'to', 'the', 'energy', 'system,', 'rather', 'than', 'forests.']
# system,
# forests.
# ['“We', 'almost', 'take', 'forests', 'as', 'a', 'given', 'but', 'we', 'lose', 'forest', 'every', 'year,', 'which', 'means', 'we', 'are', 'diminishing', 'them', 'as', 'a', 'carbon', 'sink.']
# “we
# a
# year,
# a
# sink.
# ['“It’s', 'horrifying', 'that', 'we’d', 'lose', 'our', 'biodiversity', 'to', 'avert', 'climate', 'change.']
# “it’s
# we’d
# change.
# ['Losing', 'tropical', 'forests', 'is', 'not', 'somehow', 'cheaper', 'than', 'putting', 'up', 'wind', 'farms', 'in', 'the', 'US', 'or', 'Sahara.”']
# sahara.”
# ['IPCC', 'report', 'warning', 'last', 'week', 'the', 'world', 'is', '“nowhere', 'near', 'on', 'track”', 'to', 'meet', 'its', 'Paris', 'commitments']
# “nowhere
# track”
# ['But', 'like', 'most', 'claims', 'regarding', 'global', 'warming,', 'the', 'real', 'effect', 'is', 'small,', 'probably', 'temporary,', 'and', 'most', 'likely', 'due', 'to', 'natural', 'weather', 'patterns']
# warming,
# small,
# temporary,
# ['Coastal', 'lake', 'sediments', 'along', 'the', 'Gulf', 'of', 'Mexico', 'shoreline', 'from', '1,000', 'to', '2,000', 'years', 'ago', 'suggest', 'more', 'frequent', 'and', 'intense', 'hurricanes', 'than', 'occur', 'today.']
# 1,000
# 2,000
# today.
# ['The', 'Massachusetts', 'Bay', 'Colony', 'in', '1635', 'experienced', 'a', 'Category', '3', 'or', '4', 'storm,', 'with', 'up', 'to', 'a', '20-foot', 'storm', 'surge.']
# 1635
# a
# 3
# 4
# storm,
# a
# 20-foot
# surge.
# ...
# "drowned"
# a
# ['There', 'are', 'many', 'lines', 'of', 'evidence', 'which', 'clearly', 'show', 'that', 'the', 'atmospheric', 'CO2', 'increase', 'is', 'caused', 'by', 'humans.']
# co2
# humans.
# ['The', 'clearest', 'of', 'these', 'is', 'simple', 'accounting', '-', 'humans', 'are', 'emitting', 'CO2', 'at', 'a', 'rate', 'twice', 'as', 'fast', 'as', 'the', 'atmospheric', 'increase', '(natural', 'sinks', 'are', 'absorbing', 'the', 'other', 'half).']
# -
# co2
# a
# (natural
# half).
# ['There', 'is', 'no', 'question', 'whatsoever', 'that', 'the', 'CO2', 'increase', 'is', 'human-caused.']
# co2
# human-caused.
# ['that', 'atmospheric', 'CO2', 'increase', 'that', 'we', 'observe', 'is', 'a', 'product', 'of', 'temperature', '', 'increase,', 'and', 'not', 'the', 'other', 'way', 'around,', 'meaning', 'it', 'is', 'a', 'product', 'of', '', 'natural', 'variation...']
# co2
# a
#
# increase,
# around,
# a
#
# variation...
# ['Once', 'natural', 'influences,', 'in', 'particular', 'the', 'impact', 'of', 'El', 'Niño', 'and', 'La', 'Niña,', 'are', 'removed', 'from', 'the', 'recent', 'termperature', 'record,', 'there', 'is', 'no', 'evidence', 'of', 'a', 'significant', 'change', 'in', 'the', 'human', 'contribution', 'to', 'climate', 'change.']
# influences,
# niña,
# record,
# a
# change.
# ['"...there', 'has', 'been', 'no', 'increase', 'in', 'the', 'global', 'average', 'surface', 'temperature', 'for', 'the', 'past', '16', 'years"', '(Judith', 'Curry', 'and', 'David', 'Rose)']
# "...there
# 16
# years"
# (judith
# rose)
# ['"The', 'observed', 'data', 'show', 'that', 'CFCs', 'conspiring', 'with', 'cosmic', 'rays', 'most', 'likely', 'caused', 'both', 'the', 'Antarctic', 'ozone', 'hole', 'and', 'global', 'warming...']
# "the
# warming...
# ['Correspondingly,', 'the', 'global', 'surface', 'temperature', 'has', 'also', 'dropped."']
# correspondingly,
# dropped."
# ['Models', 'and', 'direct', 'observations', 'find', 'that', 'CFCs', 'only', 'contribute', 'a', 'fraction', 'of', 'the', 'warming', 'supplied', 'by', 'other', 'greenhouse', 'gases.']
# a
# gases.
# ['This', 'increases', 'confidence', 'in', 'other', 'peer-reviewed', 'research', 'predicting', 'sea', 'level', 'rise', 'of', '80cm', 'to', '2', 'metres', 'by', '2100.']
# peer-reviewed
# 80cm
# 2
# 2100.
# ["'Another", 'global', 'warming', 'myth', 'comes', 'crashing', 'down.']
# 'another
# down.
# ['No', 'warming', 'since', 'at', 'least', '1995,', 'no', 'melting', 'glaciers', 'and', 'now', 'no', 'rising', 'sea', 'levels.']
# 1995,
# levels.
# ['The', 'claim', 'that', '2.2', 'conventional', 'jobs', 'are', 'destroyed', '', '', 'for', '', 'every', 'new', 'job', 'created', 'in', 'the', 'alternative', 'energy', 'industry', 'is', 'based', 'on', 'a', 'study', 'which', 'relies', 'on', 'incorrect', 'numbers,', 'cherrypicked', 'dates,', 'faulty', 'theory,', 'flawed', 'methodology,', 'and', 'is', 'disproven', 'by', 'real-world', 'examples.']
# 2.2
#
#
#
# a
# numbers,
# dates,
# theory,
# methodology,
# real-world
# examples.
# ['for', 'every', 'renewable', 'energy', 'job', 'that', 'the', 'State', 'manages', 'to', 'finance,', 'Spain’s', 'experience...reveals', 'with', 'high', 'confidence,', 'by', 'two', 'different', 'methods,', 'that', 'the', 'U.S.', 'should', 'expect', 'a', 'loss', 'of', 'at', 'least', '2.2', 'jobs', 'on', 'average']
# finance,
# spain’s
# experience...reveals
# confidence,
# methods,
# u.s.
# a
# 2.2
# ['Continued', 'greenhouse', 'gas', 'emissions', 'at', 'or', 'above', 'current', 'rates', 'would', 'cause', 'further', 'warming', 'and', 'induce', 'many', 'changes', 'in', 'the', 'global', 'climate', 'system', 'during', 'the', '21st', 'century', 'that', 'would', 'very', 'likely', 'be', 'larger', 'than', 'those', 'observed', 'during', 'the', '20th', 'century.']
# 21st
# 20th
# century.
# ['So', 'this', 'is', 'a', 'government', 'which', 'is', 'proposing', 'to', 'put', 'at', 'risk', 'our', 'manufacturing', 'industry,', 'to', 'penalise', 'struggling', 'families,', 'to', 'make', 'a', 'tough', 'situation', 'worse', 'for', 'millions', 'of', 'households', 'right', 'around', 'Australia.']
# a
# industry,
# families,
# a
# australia.
# ['"a', 'paper...in', 'Science', 'magazine', 'concludes', 'that', 'the', 'climate', 'sensitivity—how', 'much', 'the', 'earth’s', 'average', 'temperature', 'will', 'rise', 'as', 'a', 'result', 'of', 'a', 'doubling', 'of', 'the', 'atmospheric', 'concentration', 'of', 'carbon', 'dioxide—likely', '(that', 'is,', 'with', 'a', '66%', 'probability)', 'lies', 'in', 'the', 'range', '1.7°C', 'to', '2.6°C,', 'with', 'a', 'median', 'value', 'of', '2.3°C.']
# "a
# paper...in
# sensitivity—how
# earth’s
# a
# a
# dioxide—likely
# (that
# is,
# a
# 66%
# probability)
# 1.7°c
# 2.6°c,
# a
# 2.3°c.
# ['Fourth', 'Assessment', 'Report', '(AR4),', 'in', 'which', 'the', 'likely', 'range', 'is', 'given', 'as', '2.0°C', 'to', '4.5°C,', 'with', 'a', 'best', 'estimate', 'of', '3.0°C"', '(Pat', 'Michaels)']
# (ar4),
# 2.0°c
# 4.5°c,
# a
# 3.0°c"
# (pat
# michaels)
# ['Multiple', 'lines', 'of', 'evidence', 'indicate', "Greenland's", 'ice', 'loss', 'is', 'accelerating', 'and', 'will', 'contribute', 'sea', 'level', 'rise', 'in', 'the', 'order', 'of', 'metres', 'over', 'the', 'next', 'few', 'centuries.']
# greenland's
# centuries.
# ['This', 'was', 'the', 'case', 'last', 'year', 'too,', 'while', 'earlier', '', 'years', 'in', 'the', 'DMI', 'analysis', 'period', '(1958-2010)', 'hardly', 'ever', 'shows', 'Arctic', '', 'melt', 'season', 'temperatures', 'this', 'cold', '(Frank', 'Lansner)']
# too,
#
# (1958-2010)
#
# (frank
# lansner)
# ['"However,', 'a', 'single', 'scientist,', 'Dr.', 'Ben', 'Santer', 'of', 'Lawrence', 'Livermore', 'National', 'Laboratory,', 'rewrote', 'the', 'draft', 'at', 'the', 'IPCC’s', 'request,', 'deleting', 'all', 'five', 'statements,', 'replacing', 'them', 'with', 'a', 'single', 'statement', 'to', 'the', 'effect', 'that', 'a', 'human', 'influence', 'on', 'global', 'climate', 'was', 'now', 'discernible,', 'and', 'making', 'some', '200', 'consequential', 'amendments.']
# "however,
# a
# scientist,
# dr.
# laboratory,
# ipcc’s
# request,
# statements,
# a
# a
# discernible,
# 200
# amendments.
# ['"the', 'temperature', 'increase', 'in', 'the', 'second', 'half', 'of', 'the', '20th', 'century', 'could', 'have', 'taken', 'place', 'in', 'steps', 'driven', 'by', 'major', 'ENSO', 'events"', '(Jens', 'Raunsø', 'Jensen)']
# "the
# 20th
# events"
# (jens
# jensen)
# ['A', 'generous', 'estimate', 'of', 'the', 'energy', 'generated', 'by', 'satellites', 'is', 'around', '1', 'million', 'times', 'too', 'small', 'to', 'cause', 'global', 'warming.']
# a
# 1
# warming.
# ['Global', 'Warming', 'history', 'completely', 'coincides', 'with', 'the', 'history', 'of', 'artificial', 'satellites', 'and', 'the', 'use', 'of', 'microwave', 'frequencies', 'from', 'outer', 'space.']
# space.
# ['Sending', 'oscillating', 'microwaves', 'from', 'an', 'antenna', 'inside', 'a', 'vacuum', 'through', 'an', 'electromagnetic', 'field', 'through', 'a', 'dielectric', 'material,', 'such', 'as', 'water,', 'creates', 'radio', 'frequency', 'heating', 'at', 'the', 'molecular', 'level']
# a
# a
# material,
# water,
# ['"The', 'IPCC’s', 'Fourth', 'Assessment', 'Report,', '2007,', 'carries', 'in', 'three', 'places', 'a', 'graph', 'in', 'which', 'the', 'Hadley', 'Center’s', 'global', 'mean', 'surface', 'temperature', 'anomaly', 'dataset', 'from', '1850-2005', 'is', 'displayed', 'with', 'four', 'arbitrarily-chosen', 'trend-lines', 'overlaid', 'upon', 'it.']
# "the
# ipcc’s
# report,
# 2007,
# a
# center’s
# 1850-2005
# arbitrarily-chosen
# trend-lines
# it.
# ['...there', '[is]', 'anecdotal', 'and', 'other', 'evidence', 'suggesting', 'similar', 'melts', 'from', '1938-43', 'and', 'on', 'other', 'occasions.']
# ...there
# [is]
# 1938-43
# occasions.
# ['"Disasters', 'Cost', 'More', 'Than', 'Ever', '—', 'But', 'Not', 'Because', 'of', 'Climate', 'Change"', '(Roger', 'Pielke', 'Jr.)']
# "disasters
# —
# change"
# (roger
# jr.)
# ['the', 'satellite', 'sensors', 'show', 'less', 'warming', 'in', 'the', 'lower', 'troposphere', '(approximately', '10,000', 'feet', 'above', 'the', 'earth’s', 'surface)', 'than', 'is', 'reported', 'by', 'surface', 'temperature', 'readings.']
# (approximately
# 10,000
# earth’s
# surface)
# readings.
# ['Global', 'warming', 'theory', 'holds', 'that', 'one', 'of', 'the', 'fingerprints', 'of', 'human-induced', 'global', 'warming', 'is', 'more', 'rapid', 'warming', 'in', 'the', 'lower', 'troposphere', 'than', 'at', 'the', 'surface', '(James', 'Taylor)']
# human-induced
# (james
# taylor)
# ['In', 'those', 'days', 'you', 'couldn’t', 'have', 'seen', 'across', 'the', 'street', 'for', 'all', 'the', 'carbon', 'emissions', 'and', 'the', 'crap', 'coming', 'out', 'of', 'the', "chimneys.'"]
# couldn’t
# chimneys.'
# ["Ljungqvist's", 'millennial', 'temperature', 'reconstruction', 'was', 'very', 'similar', 'to', 'Moberg', 'et', 'al.']
# ljungqvist's
# al.
# ['It', 'also', 'concludes', 'that', 'current', 'northern', 'hemisphere', 'surface', 'air', 'temperatures', 'are', 'significantly', 'higher', 'than', 'during', 'the', 'peak', 'of', 'the', 'Medieval', 'Warm', 'Period', '(MWP).']
# (mwp).
# ["'What", 'I', 'can', 'comment', 'on', 'is', 'this', 'prediction', 'by', 'Dr.', 'Hansen:', '“The', 'West', 'Side', 'Highway', '[which', 'runs', 'along', 'the', 'Hudson', 'River]', 'will', 'be', 'under', 'water.”']
# 'what
# i
# dr.
# hansen:
# “the
# [which
# river]
# water.”
# ['CO2', 'constitutes', '80%', 'of', 'the', 'non-condensing', 'greenhouse', 'gas', 'forcing.']
# co2
# 80%
# non-condensing
# forcing.
# ['"Cloud', 'cover', 'in', 'models', 'is', 'poorly', 'treated', 'and', 'inaccurately', 'predicted.']
# "cloud
# predicted.
# ['Yet', 'clouds', 'reflect', 'about', 'seventy-five', 'watts', 'per', 'square', 'meter.']
# seventy-five
# meter.
# ['Given', 'that', 'a', 'doubling', 'of', 'carbon', 'dioxide', 'would', 'change', 'the', 'surface', 'heat', 'flux', 'by', 'only', 'two', 'watts', 'per', 'square', 'meter,', 'it', 'is', 'evident', 'that', 'a', 'small', 'change', 'in', 'cloud', 'cover', 'can', 'strongly', 'affect', 'the', 'response', 'to', 'carbon', 'dioxide."']
# a
# meter,
# a
# dioxide."
# ['the', 'Great', 'Barrier', 'Reef', 'is', 'in', 'fine', 'fettle']
# ['About', '60%', 'of', 'the', 'warming', 'observed', 'from', '1970', 'to', '2000', 'was', 'very', 'likely', 'caused', 'by', 'this', 'natural', '60-year', 'climatic', 'cycle', 'during', 'its', 'warming', 'phase...']
# 60%
# 1970
# 2000
# 60-year
# phase...
# ['"Skeptics', 'hope', 'that', 'Postma’s', 'alternative', 'thermal', 'model', 'will', 'lead', '', 'to', 'the', 'birth', 'of', 'a', 'new', 'climatology,', 'one', 'that', 'actually', 'follows', 'the', 'laws', 'of', '', 'physics', 'and', 'properly', 'physical', 'modeling', 'techniques...']
# "skeptics
# postma’s
#
# a
# climatology,
#
# techniques...
# ['"There', 'are', 'other', 'possible', 'causes', 'for', 'climate', 'change', 'which', 'could', 'be', 'associated', 'with', 'solar', 'activity', 'or', 'related', 'to', 'variations', 'in', 'the', 'temperature', 'of', 'the', 'liquid', 'core', 'of', 'the', 'Earth,', 'which', 'is', 'about', '5,400', 'degrees', 'Celsius.']
# "there
# earth,
# 5,400
# celsius.
# ['We', "don't", 'need', 'a', 'high', 'heat', 'flow', '-', 'just', 'a', 'high', 'temperature', 'for', 'the', 'core', 'to', 'affect', 'the', 'surface', 'climate.']
# don't
# a
# -
# a
# climate.
# ['Over', 'the', 'last', 'decade,', 'heatwaves', 'are', 'five', 'times', 'more', 'likely', 'than', 'if', 'there', 'had', 'been', 'no', 'global', 'warming.']
# decade,
# warming.
# 1228 1228
# Cosine similarity between 'extremes' and 'weather' - CBOW :  0.6886676
# Cosine similarity between 'greenhouse'and 'gases' - CBOW :  0.48750716
# Cosine similarity between 'greenhouse' and 'humans' - CBOW :  0.40790522
# Cosine similarity between 'greenhouse' and 'activities' - CBOW :  0.50147736
# Cosine similarity between 'greenhouse' and 'problem' - CBOW :  0.50732887
# Cosine similarity between 'greenhouse' and 'atmosphere' - CBOW :  0.36644202
# Cosine similarity between 'greenhouse' and 'carbon' - CBOW :  0.60151774
# Cosine similarity between 'greenhouse' and 'dioxide' - CBOW :  0.19718452
# Cosine similarity between 'climate' and 'change' - CBOW :  0.44768435
# [('planet', 0.4900345206260681), ('difference', 0.46835246682167053), ('dropped', 0.4626297354698181)]
# [('seas', 0.6680271625518799), ('figure', 0.6032021641731262), ('checked', 0.5651147365570068)]
# [('highs', 0.49805301427841187), ('latitude', 0.4758724868297577), ('provides', 0.46898704767227173)]
# [('extreme', 0.6334529519081116), ('stand', 0.6132005453109741), ('comparatively', 0.5976815223693848)]
# [('dead', 0.5710982084274292), ('mother', 0.5375760197639465), ('released', 0.5373622179031372)]
# [('high', 0.5910394787788391), ('lansner', 0.5632208585739136), ('winter', 0.5560482144355774)]
# <ipython-input-1-721980364c33>:61: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   print("Cosine similarity between 'extremes' " + "and 'weather' - CBOW : ", w2v_model.similarity('extremes', 'weather'))
# <ipython-input-1-721980364c33>:62: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   print("Cosine similarity between 'greenhouse'" + "and 'gases' - CBOW : ", w2v_model.similarity('greenhouse', 'gases'))
# <ipython-input-1-721980364c33>:63: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   print("Cosine similarity between 'greenhouse' " + "and 'humans' - CBOW : ", w2v_model.similarity('greenhouse', 'humans'))
# <ipython-input-1-721980364c33>:64: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   print("Cosine similarity between 'greenhouse' " + "and 'activities' - CBOW : ", w2v_model.similarity('greenhouse', 'activities'))
# <ipython-input-1-721980364c33>:65: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   print("Cosine similarity between 'greenhouse' " + "and 'problem' - CBOW : ", w2v_model.similarity('greenhouse', 'problem'))
# <ipython-input-1-721980364c33>:66: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   print("Cosine similarity between 'greenhouse' " + "and 'atmosphere' - CBOW : ", w2v_model.similarity('greenhouse', 'atmosphere'))
# <ipython-input-1-721980364c33>:67: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   print("Cosine similarity between 'greenhouse' " + "and 'carbon' - CBOW : ", w2v_model.similarity('atmosphere', 'carbon'))
# <ipython-input-1-721980364c33>:68: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   print("Cosine similarity between 'greenhouse' " + "and 'dioxide' - CBOW : ", w2v_model.similarity('greenhouse', 'dioxide'))
# <ipython-input-1-721980364c33>:69: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   print("Cosine similarity between 'climate' " + "and 'change' - CBOW : ", w2v_model.similarity('climate', 'change'))
# ['fasttext-wiki-news-subwords-300', 'conceptnet-numberbatch-17-06-300', 'word2vec-ruscorpora-300', 'word2vec-google-news-300', 'glove-wiki-gigaword-50', 'glove-wiki-gigaword-100', 'glove-wiki-gigaword-200', 'glove-wiki-gigaword-300', 'glove-twitter-25', 'glove-twitter-50', 'glove-twitter-100', 'glove-twitter-200', '__testing_word2vec-matrix-synopsis']
# [('temperatures', 0.8621711730957031), ('humidity', 0.8255164623260498), ('precipitation', 0.7735739946365356), ('celsius', 0.7568027973175049), ('heat', 0.7556609511375427), ('degrees', 0.7470089793205261), ('normal', 0.7429028749465942), ('cooling', 0.7355426549911499), ('varies', 0.7315371036529541), ('depending', 0.7311199903488159)]
# [('temperatures', 0.8238509893417358), ('ambient_temperature', 0.7584964036941528), ('Temperature', 0.7231121063232422), ('degrees_Fahrenheit', 0.6730053424835205), ('°_C', 0.6674304008483887), ('ambient_temperatures', 0.6562219858169556), ('humidity', 0.6416519284248352), ('°_F', 0.6414622068405151), ('dewpoint', 0.6287775635719299), ('daytime_temperatures', 0.6258816719055176)]
